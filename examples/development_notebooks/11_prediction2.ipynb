# %%
# Reloading modules for interactive development
# %load_ext autoreload
# %autoreload 2

from hydroml.workflow.prediction import run_hydrological_simulation
import pandas as pd
import numpy as np

# Example inputs
model_path = 'P://work//sho108//hydroml//results//default//241209224715_cdae'

length = 300
dynamic_data = pd.DataFrame(
    data=np.random.rand(length,2)*100,  # Example dynamic data
    columns=['precipitation_AWAP', 'et_morton_wet_SILO'], 
    index=pd.date_range(start='2024-01-01', periods=length, freq='D')
)

catchment_id = '000000'

# Run the simulation
# ['catchment_area', 'mean_slope_pct', 'prop_forested', 'upsdist','strdensity' ,'strahler','frac_snow','p_seasonality', 'p_mean', 'pet_mean','aridity' ,'high_prec_freq' ,'high_prec_dur']
static_data = [1000, 10, 50, 5, 1, 2, 0.1, 0.5, 800, 20, 0.2, 15, 5]  # Example static features
simulation = run_hydrological_simulation(model_path, dynamic_data, static_data, catchment_id)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# c:\Users\sho108\AppData\Local\pypoetry\Cache\virtualenvs\hydroml-dFLAodHf-py3.11\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\sho108\AppData\Local\pypoetry\Cache\virtualenvs\hydroml-dFLAodHf-py3.11\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
